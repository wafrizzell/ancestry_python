# %%
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
### SET GLOBAL VARIABLES ###

your_ged_id = "A445182"   # Put your GED Match ID here as a string
auto_id_list = True      # Set to true to create list of ged_ids from directory, false to manually select ged_ids
directory = "../Gephi2024/Import_Files/"    # Set directory to write csv output to

# Insert a list of ged_ids you want to parse
manual_id_list = []
ged_ids = []

edges = pd.DataFrame()
nodes = pd.DataFrame()

# %%
### CREATE OR RESET CSV FILES ###

header = pd.DataFrame(["target","name", "main_cm", "main_long", "main_gen", "match_cm",
                       "match_long", "match_gen", "gen_diff", "tree", "email", "main_id", "match_id"]).T

if os.path.isfile(f"{directory}shared_master.csv"):
    print("shared_master.csv already exists")
else:
    header.to_csv(f"{directory}shared_master.csv", header=False, index=False)
    print("shared_master.csv created and header wrote to file")
# Out:
# shared_master.csv created and header wrote to file

# %%
### CREATE GED_ID LIST ###

# Add from directory if auto is true, or from manual_id_list if auto is false
if auto_id_list == True:
    for filename in os.listdir(os.getcwd()):
        if filename.endswith('.html'):
            ged_ids.append(filename[:-5])
else:
    ged_ids = manual_id_list

# %%
### USE BEAUTIFUL SOUP TO PARSE HTML FILES FROM GED ID LIST ###

# Iterate through each html file using ged_ids
for ged_id in ged_ids:
    match_id = ged_id
    
    # Parse the html file
    gedMatch_html = open(f"{match_id}.html",encoding="utf8")
    soup = BeautifulSoup(gedMatch_html, "html.parser")

    # Find table and get table rows and create match_data
    table = soup.find("table", attrs={"class":"results-table"})
    table_rows = table.find_all("tr")

    match_data = []
    for row in table.find_all("tr"):
        row_data = []
        for cell in row.find_all("td"):
            row_data.append(cell.text)
        match_data.append(row_data)
    
    # Create the dataframe
    df = pd.DataFrame(match_data)
    
    # Close the open file after dataframe is made
    gedMatch_html.close()
    
    
### CREATE NODES AND EDGES DATAFRAMES ###   
    
    # Create edge dataframes and then concat into one dataframe
    ### CLEAN AND PREPARE DATAFRAME ###
    
     # Add new columns
    df[12] = your_ged_id
    df[13] = f"{match_id}"

     # Drop empty rows and unused columns and reset the index
    df.drop([0, 1], inplace=True)
    df.drop([1], inplace=True, axis=1)
    df.reset_index(drop=True, inplace=True)

     # Rename columns
    df.columns =["target","name", "main_cm", "main_longest", "main_gen", "match_cm", "match_long",
    "match_gen", "gen_diff", "tree", "email", "main_id", "match_id"]

    # Recast numeric columns as floats
    df["main_cm"] = df["main_cm"].str.replace(',', '').astype("float")
    df["main_longest"] = df["main_longest"].astype("float")
    df["main_gen"] = df["main_gen"].astype("float")
    df["match_cm"] = df["match_cm"].str.replace(',', '').astype("float")
    df["match_long"] = df["match_long"].astype("float")
    df["match_gen"] = df["match_gen"].astype("float")
    df["gen_diff"] = df["gen_diff"].astype("float")

    # Save to shared_master.csv
    df.to_csv(f"{directory}shared_master.csv", mode="a", header=False, index=False)
    print(f"Appended {match_id} to shared_master.csv")
# Out:
# Appended A005048 to shared_master.csv
# Appended A007587 to shared_master.csv
# Appended A008390 to shared_master.csv
# Appended A024726 to shared_master.csv
# Appended A033095 to shared_master.csv
# Appended A046943 to shared_master.csv
# Appended A050279 to shared_master.csv
# Appended A068570 to shared_master.csv
# Appended A078377 to shared_master.csv
# Appended A083036 to shared_master.csv
# Appended A115797 to shared_master.csv
# Appended A122366 to shared_master.csv
# Appended A172685 to shared_master.csv
# Appended A182730 to shared_master.csv
# Appended A195588 to shared_master.csv
# Appended A195755 to shared_master.csv
# Appended A199479 to shared_master.csv
# Appended A213723 to shared_master.csv
# Appended A227609 to shared_master.csv
# Appended A245559 to shared_master.csv
# Appended A265533 to shared_master.csv
# Appended A268000 to shared_master.csv
# Appended A311042 to shared_master.csv
# Appended A313175 to shared_master.csv
# Appended A318102 to shared_master.csv
# Appended A324230 to shared_master.csv
# Appended A344316 to shared_master.csv
# Appended A355405 to shared_master.csv
# Appended A366378 to shared_master.csv
# Appended A369791 to shared_master.csv
# Appended A375515 to shared_master.csv
# Appended A380565 to shared_master.csv
# Appended A398274 to shared_master.csv
# Appended A398870 to shared_master.csv
# Appended A420470 to shared_master.csv
# Appended A427327 to shared_master.csv
# Appended A429925 to shared_master.csv
# Appended A455770 to shared_master.csv
# Appended A457247 to shared_master.csv
# Appended A459788 to shared_master.csv
# Appended A499725 to shared_master.csv
# Appended A546803 to shared_master.csv
# Appended A582117 to shared_master.csv
# Appended A591144 to shared_master.csv
# Appended A627140 to shared_master.csv
# Appended A637470 to shared_master.csv
# Appended A661044 to shared_master.csv
# Appended A662421 to shared_master.csv
# Appended A680411 to shared_master.csv
# Appended A683779 to shared_master.csv
# Appended A684443 to shared_master.csv
# Appended A699548 to shared_master.csv
# Appended A704422 to shared_master.csv
# Appended A718760 to shared_master.csv
# Appended A721427 to shared_master.csv
# Appended A725191 to shared_master.csv
# Appended A764094 to shared_master.csv
# Appended A854177 to shared_master.csv
# Appended A865831 to shared_master.csv
# Appended A876924 to shared_master.csv
# Appended A920190 to shared_master.csv
# Appended A927216 to shared_master.csv
# Appended A931475 to shared_master.csv
# Appended A943947 to shared_master.csv
# Appended A944831 to shared_master.csv
# Appended A955088 to shared_master.csv
# Appended AZ2693023 to shared_master.csv
# Appended AZ6213436 to shared_master.csv
# Appended BA8594640 to shared_master.csv
# Appended BB6957765 to shared_master.csv
# Appended BH9810308 to shared_master.csv
# Appended BK7964209 to shared_master.csv
# Appended BQ8038683 to shared_master.csv
# Appended BV6192805 to shared_master.csv
# Appended CA7688039 to shared_master.csv
# Appended CB6148485 to shared_master.csv
# Appended CF5648174 to shared_master.csv
# Appended CJ7502533 to shared_master.csv
# Appended DM1066832 to shared_master.csv
# Appended DS5487294 to shared_master.csv
# Appended EP5453655 to shared_master.csv
# Appended EY2933526 to shared_master.csv
# Appended FA1293905 to shared_master.csv
# Appended FS026156C1 to shared_master.csv
# Appended FT9172213 to shared_master.csv
# Appended FU2571459 to shared_master.csv
# Appended FY4162947 to shared_master.csv
# Appended GM3784447 to shared_master.csv
# Appended GT2163037 to shared_master.csv
# Appended H416083 to shared_master.csv
# Appended HA9368773 to shared_master.csv
# Appended HB6603003 to shared_master.csv
# Appended HK4944976 to shared_master.csv
# Appended JA3375475 to shared_master.csv
# Appended JS8796188 to shared_master.csv
# Appended JU8160773 to shared_master.csv
# Appended KC4549308 to shared_master.csv
# Appended KP7709976 to shared_master.csv
# Appended LA9874436 to shared_master.csv
# Appended LD6428144 to shared_master.csv
# Appended LF5490888 to shared_master.csv
# Appended LK8998008 to shared_master.csv
# Appended LR9426891 to shared_master.csv
# Appended M104341 to shared_master.csv
# Appended M120933 to shared_master.csv
# Appended M241543 to shared_master.csv
# Appended M384577 to shared_master.csv
# Appended M414013 to shared_master.csv
# Appended M464691 to shared_master.csv
# Appended M490247 to shared_master.csv
# Appended M594527 to shared_master.csv
# Appended M687594 to shared_master.csv
# Appended M741893 to shared_master.csv
# Appended ME9192173 to shared_master.csv
# Appended MF9506137 to shared_master.csv
# Appended MJ3959069 to shared_master.csv
# Appended MM2289940 to shared_master.csv
# Appended MU4742441 to shared_master.csv
# Appended NK3706768 to shared_master.csv
# Appended NQ3560095 to shared_master.csv
# Appended PG6174337 to shared_master.csv
# Appended PJ3052072 to shared_master.csv
# Appended PR1835364 to shared_master.csv
# Appended QD9884769 to shared_master.csv
# Appended QG2182821 to shared_master.csv
# Appended QL6379034 to shared_master.csv
# Appended QQ5823295 to shared_master.csv
# Appended QX2202465 to shared_master.csv
# Appended QY9369344 to shared_master.csv
# Appended RM1409135 to shared_master.csv
# Appended RQ3314375 to shared_master.csv
# Appended SD4763449 to shared_master.csv
# Appended SP8745883 to shared_master.csv
# Appended SW9841654 to shared_master.csv
# Appended SY3556612 to shared_master.csv
# Appended T236915 to shared_master.csv
# Appended T310781 to shared_master.csv
# Appended T377862 to shared_master.csv
# Appended T391930 to shared_master.csv
# Appended T529415 to shared_master.csv
# Appended T538957 to shared_master.csv
# Appended T596736 to shared_master.csv
# Appended T626480 to shared_master.csv
# Appended T667513 to shared_master.csv
# Appended T719130 to shared_master.csv
# Appended TF1360118 to shared_master.csv
# Appended TG6061156 to shared_master.csv
# Appended UR5098028 to shared_master.csv
# Appended WP4802642 to shared_master.csv
# Appended WR5697457 to shared_master.csv
# Appended WV6571162 to shared_master.csv
# Appended XE3446978 to shared_master.csv
# Appended XF3426993 to shared_master.csv
# Appended XL3052261 to shared_master.csv
# Appended XX7320466 to shared_master.csv
# Appended YG9756632 to shared_master.csv
# Appended YG9844517 to shared_master.csv
# Appended YJ1893714 to shared_master.csv
# Appended YK4576387 to shared_master.csv
# Appended YM3561700 to shared_master.csv
# Appended ZC7060781 to shared_master.csv
# Appended ZE4463791 to shared_master.csv
# Appended ZT5002687 to shared_master.csv
# Appended ZW1338832 to shared_master.csv

# %% [markdown]
# Need to fix values in GED, Wiki, GED Wiki
# Compare file size of complete web pages versus shared_master
# Find a way to check to see if file has already been saved - Add IDs saved to a csv and then compare with a list to download to make a final list - Use match_id unique
# Install Git and Visual Studio
